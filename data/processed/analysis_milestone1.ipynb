# %%
import pandas as pd

# %%
pd.read_csv("Lower_Mainland_Crashes_Full_Data_data.csv")
# Out:
#         Latitude   Longitude  \
# 0      49.265063 -123.119811
# 1      49.265072 -123.175900
# 2      49.265079 -123.069740
# 3      49.265083 -123.121774
# 4      49.265199 -123.079402
# ...          ...         ...
# 28744  49.272815 -123.100019
# 28745  49.210132 -123.117149
# 28746  49.234343 -123.139623
# 28747  49.232292 -123.023538
# 28748  49.258209 -123.023636
#
#                                                 Location Municipality  \
# 0                                 HEATHER ST & W 7TH AVE    VANCOUVER
# 1                                  TRUTCH ST & W 8TH AVE    VANCOUVER
# 2                              COMMERCIAL DR & E 6TH AVE    VANCOUVER
# 3                                  W 7TH AVE & WILLOW ST    VANCOUVER
# 4                                   E 6TH AVE & KEITH DR    VANCOUVER
# ...                                                  ...          ...
# 28744                             MAIN ST & TERMINAL AVE    VANCOUVER
# ...

# %%
df=pd.read_csv("Lower_Mainland_Crashes_Full_Data_data.csv")
df.head(5)
# Out:
#     Latitude   Longitude                   Location Municipality Crash Type  \
# 0  49.265063 -123.119811     HEATHER ST & W 7TH AVE    VANCOUVER   Casualty
# 1  49.265072 -123.175900      TRUTCH ST & W 8TH AVE    VANCOUVER   Casualty
# 2  49.265079 -123.069740  COMMERCIAL DR & E 6TH AVE    VANCOUVER   Casualty
# 3  49.265083 -123.121774      W 7TH AVE & WILLOW ST    VANCOUVER   Casualty
# 4  49.265199 -123.079402       E 6TH AVE & KEITH DR    VANCOUVER   Casualty
#
#    Year  Crash Count
# 0  2016            2
# 1  2016            1
# 2  2016            2
# 3  2016            1
# 4  2016            5
